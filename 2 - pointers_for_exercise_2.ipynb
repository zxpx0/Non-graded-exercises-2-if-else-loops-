# %% [markdown]
# enumerate() method:

# %%
str1 = "Howl's Moving Castle"

# %% [markdown]
# join() method:

# %%
some_list = ['Baa', 'baa', 'black', 'sheep']

# %% [markdown]
# random() method:

# %%
some_list = ['Baa', 'baa', 'black', 'sheep']
# Out:
# sheep
